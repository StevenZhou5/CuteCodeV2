# %% [markdown]
# # ANN召回算法之HNSW
#
# 相关介绍链接：https://zhuanlan.zhihu.com/p/379372268

# %% [markdown]
# # HNSW算法开源库对比
#
# facebookresearch/faiss: A library for efficient similarity search and clustering of dense vectors. (github.com)
#
# nmslib/hnswlib: Header-only C++/python library for fast approximate nearest neighbors (github.com)
#
# nmslib/hnswlib: Header-only C++/python library for fast approximate nearest neighbors (github.com)
#
# ![HNSW%E5%BC%80%E6%BA%90%E5%BA%93%E5%AF%B9%E6%AF%94.png](attachment:HNSW%E5%BC%80%E6%BA%90%E5%BA%93%E5%AF%B9%E6%AF%94.png)
# ![2.png](attachment:2.png)
# ![3.png](attachment:3.png)
# ![4.png](attachment:4.png)
