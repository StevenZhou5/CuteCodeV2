# %%
import pandas as pd

#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', 50)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %%
pd.read_csv("carDataDealTest/test.csv")
# Out:
#     car_id  model_id                               title car_country  \
# 0     3375    2166.0              马自达-6 2010款 2.0L 自动时尚型          日系
# 1     4770   10054.0              宝马-3系 2012款 320i 自动豪华型          德系
# 2     6915    8099.0              斯柯达-明锐2013款 1.6L 自动逸致版          其他
# 3     9450    6155.0            奔驰-CLS级 2012款 CLS300 CGI          德系
# 4    10230    9928.0            雪佛兰-科鲁兹 2013款 1.6L SE MT          美系
# 5    13080    6836.0              日产-骐达2011款 1.6L CVT智能型          日系
# 6    13395    1991.0        广汽乘用车-传祺GA5 2012款 1.8L 手动精英型          国产
# 7    14565   13982.0                雪佛兰-乐风2010款 1.4MT风度版          美系
# 8    14790   11766.0           大众-途观2012款 1.8TSI 手动两驱进享版          德系
# 9    20040    1383.0    长安汽车-奔奔MINI 2012款 1.0L 手动亲情版 国IV          国产
# 10   20115   13654.0            斯柯达-昊锐2009款 1.8TSI 自动尊雅版          其他
# 11   20220   12861.0                宝马-1系 2008款 120i 自动挡          德系
# 12   21015   17385.0         马自达-3(进口) 2010款 两厢 1.6自动豪华型          日系
# ...
